# %%
#how to import requirement libaray
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#how to load the data set
df = pd.read_csv("/content/drive/MyDrive/twitter_training1.csv",encoding = 'unicode_escape')

# %%
#how to check shape of the data set
print("The shape of the data set:", df.shape)
# Out:
# The shape of the data set: (14822, 5)

# %%
#how to chekc header section
df.head()
# Out:
#      id             name  Borderlands     Cheat  \
# 0  2401          barjraj  Borderlands  Positive
# 1  2401          barjraj  Borderlands  Positive
# 2  2401     ramdin verma  Borderlands  Positive
# 3  2401  sharat chandran  Borderlands  Positive
# 4  2401  birender mandal  Borderlands  Positive
#
#                                              message
# 0  im getting on borderlands and i will murder yo...
# 1  I am coming to the borders and I will kill you...
# 2  im getting on borderlands and i will kill you ...
# 3  im coming on borderlands and i will murder you...
# 4  im getting on borderlands 2 and i will murder ...

# %%
#how to check footer section
df.head()
# Out:
#      id             name  Borderlands     Cheat  \
# 0  2401          barjraj  Borderlands  Positive
# 1  2401          barjraj  Borderlands  Positive
# 2  2401     ramdin verma  Borderlands  Positive
# 3  2401  sharat chandran  Borderlands  Positive
# 4  2401  birender mandal  Borderlands  Positive
#
#                                              message
# 0  im getting on borderlands and i will murder yo...
# 1  I am coming to the borders and I will kill you...
# 2  im getting on borderlands and i will kill you ...
# 3  im coming on borderlands and i will murder you...
# 4  im getting on borderlands 2 and i will murder ...

# %%
#how to check column name
df.columns
# Out:
# Index(['id', 'name', 'Borderlands', 'Cheat', 'message'], dtype='object')

# %%
#how to check unique value
df['Cheat'].unique()
# Out:
# array(['Positive', 'Neutral', 'Negative', 'Irrelevant'], dtype=object)

# %%
#how to check column name
df.columns
# Out:
# Index(['id', 'name', 'Borderlands', 'Cheat', 'message'], dtype='object')

# %%
#how to check data types
df.dtypes
# Out:
# id              int64
# name           object
# Borderlands    object
# Cheat          object
# message        object
# dtype: object

# %%
#how to check info of the data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14822 entries, 0 to 14821
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           14822 non-null  int64
#  1   name         14822 non-null  object
#  2   Borderlands  14822 non-null  object
#  3   Cheat        14822 non-null  object
#  4   message      14661 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 579.1+ KB

# %%
#how to chekc null values in pandas data frame
df.isnull().sum()
# Out:
# id               0
# name             0
# Borderlands      0
# Cheat            0
# message        161
# dtype: int64

# %%
#how to visulize the column
sns.countplot(x='Cheat', data=df)

# %%
# 20 largest values in column id
df.nlargest(20, ['id'])
# Out:
#           id            name    Borderlands       Cheat  \
# 11619  13200            amit  Xbox(Xseries)  Irrelevant
# 11620  13200          kushal  Xbox(Xseries)  Irrelevant
# 11621  13200           kasid  Xbox(Xseries)  Irrelevant
# 11622  13200    shiv prakash  Xbox(Xseries)  Irrelevant
# 11623  13200    vikram singh  Xbox(Xseries)  Irrelevant
# 11624  13200          sanjay  Xbox(Xseries)  Irrelevant
# 11613  13199    vikram singh  Xbox(Xseries)  Irrelevant
# 11614  13199          sanjay  Xbox(Xseries)  Irrelevant
# 11615  13199            abhi  Xbox(Xseries)  Irrelevant
# 11616  13199  ram dutt gupta  Xbox(Xseries)  Irrelevant
# 11617  13199    khadak singh  Xbox(Xseries)  Irrelevant
# 11618  13199    gurmit singh  Xbox(Xseries)  Irrelevant
# 11607  13198    khadak singh  Xbox(Xseries)    Positive
# 11608  13198    gurmit singh  Xbox(Xseries)    Positive
# 11609  13198            amit  Xbox(Xseries)    Positive
# 11610  13198          kushal  Xbox(Xseries)    Positive
# ...

# %%
#top 20 name corresponding cheat 
df.sort_values(['name', 'Cheat', 'message'], ascending=False).groupby('name').head(20)
# Out:
#           id          name                Borderlands     Cheat  \
# 11011  13096  vikram singh              Xbox(Xseries)  Positive
# 13381   8700  vikram singh                      NBA2K  Positive
# 4497    1975  vikram singh  CallOfDutyBlackopsColdWar  Positive
# 7149    9232  vikram singh                  Overwatch  Positive
# 2773    1682  vikram singh  CallOfDutyBlackopsColdWar  Positive
# ...      ...           ...                        ...       ...
# 351     2459          abhi                Borderlands  Positive
# 1983    2749          abhi                Borderlands  Positive
# 8953    9540          abhi                  Overwatch  Positive
# 8103    9395          abhi                  Overwatch  Positive
# 9439   12826          abhi              Xbox(Xseries)  Positive
#
#                                                  message
# 11011  youtu. com be / O2nNljv0MOw. com This internet...
# 13381                                                you
# ...

# %%
# display top 40 cheat of the specific columns names using header section
df[['name', 'Cheat', 'message']].head(40)
# Out:
#                name     Cheat  \
# 0           barjraj  Positive
# 1           barjraj  Positive
# 2      ramdin verma  Positive
# 3   sharat chandran  Positive
# 4   birender mandal  Positive
# 5              amit  Positive
# 6            kushal  Positive
# 7             kasid  Positive
# 8      shiv prakash  Positive
# 9      vikram singh  Positive
# 10           sanjay  Positive
# 11             abhi  Positive
# 12   ram dutt gupta   Neutral
# 13     khadak singh   Neutral
# 14     gurmit singh   Neutral
# 15             amit   Neutral
# 16           kushal   Neutral
# 17            kasid   Neutral
# 18     shiv prakash  Positive
# 19     vikram singh  Positive
# 20           sanjay  Positive
# 21             abhi  Positive
# 22   ram dutt gupta  Positive
# 23     khadak singh  Positive
# 24     gurmit singh  Negative
# 25             amit  Negative
# 26           kushal  Negative
# 27            kasid  Negative
# 28     shiv prakash  Negative
# 29     vikram singh  Negative
# ...
