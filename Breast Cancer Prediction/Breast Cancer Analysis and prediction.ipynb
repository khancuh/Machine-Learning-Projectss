# %% [markdown]
# # Some import Important Library

# %%
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load The Data set

# %%
df = pd.read_csv('C:\\Users\\Imran\\Desktop\\Breast Cancer dataset.csv')

# %%
df.head(5)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.dtypes
# Out:
# id                           int64
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# ...

# %%
df.keys()
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
# id                         569 non-null int64
# diagnosis                  569 non-null object
# radius_mean                569 non-null float64
# texture_mean               569 non-null float64
# perimeter_mean             569 non-null float64
# area_mean                  569 non-null float64
# smoothness_mean            569 non-null float64
# compactness_mean           569 non-null float64
# concavity_mean             569 non-null float64
# concave points_mean        569 non-null float64
# symmetry_mean              569 non-null float64
# fractal_dimension_mean     569 non-null float64
# radius_se                  569 non-null float64
# texture_se                 569 non-null float64
# perimeter_se               569 non-null float64
# area_se                    569 non-null float64
# smoothness_se              569 non-null float64
# ...

# %%
df['diagnosis'].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %% [markdown]
# # Imbalanced Visulization Target

# %%
sns.countplot(x='diagnosis',data=df)

# %%
df.groupby('diagnosis').size()
# Out:
# diagnosis
# B    357
# M    212
# dtype: int64

# %%
# 212/(357+212)

# %% [markdown]
# # convert Target into Binary Form

# %%
dict1 ={'M':0,'B':1}
df.replace({'diagnosis':dict1},inplace=True)

# %%
df.head(5)
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          0        17.99         10.38          122.80     1001.0
# 1    842517          0        20.57         17.77          132.90     1326.0
# 2  84300903          0        19.69         21.25          130.00     1203.0
# 3  84348301          0        11.42         20.38           77.58      386.1
# 4  84358402          0        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# # Divide the Data set Indepandant and Depandant Variable

# %%
real_x = df.iloc[:,2:32]
real_y = df.iloc[:,1]

# %%
real_x
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
real_y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 564    0
# 565    0
# 566    0
# 567    0
# 568    1
# Name: diagnosis, Length: 569, dtype: int64

# %% [markdown]
# # feature Scaling using MinMax Scaler

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
scaler.fit(real_x)
# Out:
# MinMaxScaler()

# %%
data_scaled = scaler.transform(real_x)

# %%
real_X = pd.DataFrame(data=data_scaled)

# %%
real_X
# Out:
#            0         1         2         3         4         5         6   \
# 0    0.521037  0.022658  0.545989  0.363733  0.593753  0.792037  0.703140
# 1    0.643144  0.272574  0.615783  0.501591  0.289880  0.181768  0.203608
# 2    0.601496  0.390260  0.595743  0.449417  0.514309  0.431017  0.462512
# 3    0.210090  0.360839  0.233501  0.102906  0.811321  0.811361  0.565604
# 4    0.629893  0.156578  0.630986  0.489290  0.430351  0.347893  0.463918
# ..        ...       ...       ...       ...       ...       ...       ...
# 564  0.690000  0.428813  0.678668  0.566490  0.526948  0.296055  0.571462
# 565  0.622320  0.626987  0.604036  0.474019  0.407782  0.257714  0.337395
# 566  0.455251  0.621238  0.445788  0.303118  0.288165  0.254340  0.216753
# 567  0.644564  0.663510  0.665538  0.475716  0.588336  0.790197  0.823336
# 568  0.036869  0.501522  0.028540  0.015907  0.000000  0.074351  0.000000
#
#            7         8         9   ...        20        21        22  \
# ...

# %%
print(df.columns.tolist())
# Out:
# ['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst']

# %%
real_X.columns = ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se', 
                  'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst',
                  'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst']

# %%
real_X
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0       0.521037      0.022658        0.545989   0.363733         0.593753
# 1       0.643144      0.272574        0.615783   0.501591         0.289880
# 2       0.601496      0.390260        0.595743   0.449417         0.514309
# 3       0.210090      0.360839        0.233501   0.102906         0.811321
# 4       0.629893      0.156578        0.630986   0.489290         0.430351
# ..           ...           ...             ...        ...              ...
# 564     0.690000      0.428813        0.678668   0.566490         0.526948
# 565     0.622320      0.626987        0.604036   0.474019         0.407782
# 566     0.455251      0.621238        0.445788   0.303118         0.288165
# 567     0.644564      0.663510        0.665538   0.475716         0.588336
# 568     0.036869      0.501522        0.028540   0.015907         0.000000
#
# ...

# %%
real_y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 564    0
# 565    0
# 566    0
# 567    0
# 568    1
# Name: diagnosis, Length: 569, dtype: int64

# %% [markdown]
# # Feature Selection

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
X_real = SelectKBest(score_func=chi2, k=10).fit_transform(real_X,real_y)

# %%
X_real
# Out:
# array([[0.52103744, 0.54598853, 0.36373277, ..., 0.45069799, 0.56861022,
#         0.91202749],
#        [0.64314449, 0.61578329, 0.50159067, ..., 0.43521431, 0.19297125,
#         0.63917526],
#        [0.60149557, 0.59574321, 0.44941676, ..., 0.37450845, 0.35974441,
#         0.83505155],
#        ...,
#        [0.45525108, 0.44578813, 0.30311771, ..., 0.23073142, 0.27180511,
#         0.48728522],
#        [0.64456434, 0.66553797, 0.4757158 , ..., 0.402035  , 0.74976038,
#         0.91065292],
#        [0.03686876, 0.02853984, 0.01590668, ..., 0.02049744, 0.        ,
#         0.        ]])

# %% [markdown]
# # Feature Importance

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
model = ExtraTreesClassifier()
model.fit(real_x,real_y)
feature_importance = print(model.feature_importances_)
feat_importances = pd.Series(model.feature_importances_,index=real_X.columns)
# Out:
# [0.05311227 0.01629114 0.0541074  0.069738   0.00990899 0.0311951
#  0.06639823 0.04820736 0.00711359 0.00597312 0.03496972 0.00534765
#  0.01788315 0.03240631 0.00693314 0.00812328 0.00748072 0.00810134
#  0.00480878 0.00787572 0.11094142 0.02712737 0.08123788 0.09742458
#  0.0251246  0.03695031 0.0321527  0.07014322 0.01455153 0.00837139]

# %% [markdown]
# # Plot graph feature importances bettter visulization

# %%
plt.figure(figsize=(20,20))
feat_importances.nlargest(20).plot(kind='barh')
plt.show()

# %% [markdown]
# # Correlation Matrix

# %%
corr = df.corr()
top_feat_importances = corr.index
plt.figure(figsize=(20,20))
g=sns.heatmap(df[top_feat_importances].corr(), annot=True, cmap="RdYlGn")

# %% [markdown]
# # Balance the Data set using RandomUnderSampler

# %%
from imblearn.under_sampling import RandomUnderSampler
undersample = RandomUnderSampler()

# %%
 X_under, y_under = undersample.fit_sample(X_real,real_y)

# %%
df = pd.DataFrame(y_under)

# %% [markdown]
# # Balance Data Visulization using random Under sampling

# %%
sns.countplot(x='diagnosis',data=df)

# %% [markdown]
# # spliting the data set

# %%
from sklearn.model_selection import train_test_split

# %%
training_x,test_x, training_y,test_y = train_test_split(X_under,y_under,test_size=0.3,random_state=12345)
training_y
# Out:
# 30     0
# 51     0
# 249    1
# 209    0
# 376    1
#       ..
# 357    1
# 382    1
# 420    1
# 129    0
# 285    1
# Name: diagnosis, Length: 296, dtype: int64

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(training_x,training_y)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(test_x)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
print(confusion_matrix(test_y,y_pred))
print("##############################################################")
print(classification_report(test_y,y_pred))
print("Visulization Confusion Matrix")
cm = confusion_matrix(test_y,y_pred)
sns.heatmap(cm, annot=True)
# Out:
# [[60  5]
#  [ 3 60]]
# ##############################################################
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.94        65
#            1       0.92      0.95      0.94        63
#
#     accuracy                           0.94       128
#    macro avg       0.94      0.94      0.94       128
# weighted avg       0.94      0.94      0.94       128
#
# Visulization Confusion Matrix

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(test_y,y_pred)
# Out:
# 0.9375

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DT = DecisionTreeClassifier()
DT.fit(training_x,training_y)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = DT.predict(test_x)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
print(confusion_matrix(test_y,y_pred))
print("##################################################################")
print(classification_report(test_y,y_pred))
print("Visulization Confusion Matix")
cm = confusion_matrix(test_y,y_pred)
sns.heatmap(cm,annot=True)
# Out:
# [[62  3]
#  [ 6 57]]
# ##################################################################
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93        65
#            1       0.95      0.90      0.93        63
#
#     accuracy                           0.93       128
#    macro avg       0.93      0.93      0.93       128
# weighted avg       0.93      0.93      0.93       128
#
# Visulization Confusion Matix

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(test_y,y_pred)
# Out:
# 0.9296875

# %% [markdown]
# # KNNClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()
knn.fit(training_x,training_y)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(test_x)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
print(confusion_matrix(test_y,y_pred))
print("###############################################################")
print(classification_report(test_y,y_pred))
print("Visulization confusion_matrix")
cm = confusion_matrix(test_y,y_pred)
sns.heatmap(cm,annot=True)
# Out:
# [[64  1]
#  [ 3 60]]
# ###############################################################
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97        65
#            1       0.98      0.95      0.97        63
#
#     accuracy                           0.97       128
#    macro avg       0.97      0.97      0.97       128
# weighted avg       0.97      0.97      0.97       128
#
# Visulization confusion_matrix

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(test_y,y_pred)
# Out:
# 0.96875

# %% [markdown]
# # SVM Classifier

# %%
from sklearn.svm import SVC

# %%
svc = SVC()
svc.fit(training_x,training_y)
# Out:
# SVC()

# %%
y_pred = svc.predict(test_x)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
print(confusion_matrix(test_y,y_pred))
print("############################################################")
print(classification_report(test_y,y_pred))
print("Visulization confusion_matrix")
cm = confusion_matrix(test_y,y_pred)
sns.heatmap(cm,annot=True)
# Out:
# [[62  3]
#  [ 2 61]]
# ############################################################
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96        65
#            1       0.95      0.97      0.96        63
#
#     accuracy                           0.96       128
#    macro avg       0.96      0.96      0.96       128
# weighted avg       0.96      0.96      0.96       128
#
# Visulization confusion_matrix

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(test_y,y_pred)
# Out:
# 0.9609375

# %% [markdown]
# # Stock Hosting Gradient Decent Classifier

# %%
from sklearn.linear_model import SGDClassifier

# %%
sgd = SGDClassifier()
sgd.fit(training_x,training_y)
# Out:
# SGDClassifier()

# %%
y_pred = sgd.predict(test_x)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
print(confusion_matrix(test_y,y_pred))
print("############################################################")
print(classification_report(test_y,y_pred))
print("Visulization Confusion Matrix")
cm = confusion_matrix(test_y,y_pred)
sns.heatmap(cm,annot=True)
# Out:
# [[57  8]
#  [ 0 63]]
# ############################################################
#               precision    recall  f1-score   support
#
#            0       1.00      0.88      0.93        65
#            1       0.89      1.00      0.94        63
#
#     accuracy                           0.94       128
#    macro avg       0.94      0.94      0.94       128
# weighted avg       0.94      0.94      0.94       128
#
# Visulization Confusion Matrix

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(test_y,y_pred)
# Out:
# 0.9375

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
RFC = RandomForestClassifier()
RFC.fit(training_x,training_y)
# Out:
# RandomForestClassifier()

# %%
y_pred = RFC.predict(test_x)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
print(confusion_matrix(test_y,y_pred))
print("############################################################")
print(classification_report(test_y,y_pred))
print("Visulization Confusion Matrix")
cm = confusion_matrix(test_y,y_pred)
sns.heatmap(cm,annot=True)
# Out:
# [[64  1]
#  [ 2 61]]
# ############################################################
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98        65
#            1       0.98      0.97      0.98        63
#
#     accuracy                           0.98       128
#    macro avg       0.98      0.98      0.98       128
# weighted avg       0.98      0.98      0.98       128
#
# Visulization Confusion Matrix

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(test_y,y_pred)
# Out:
# 0.9765625

# %% [markdown]
# # Bagging Classifier

# %%
from sklearn.ensemble import BaggingClassifier

# %%
BC = BaggingClassifier()
BC.fit(training_x,training_y)
# Out:
# BaggingClassifier()

# %%
y_pred = BC.predict(test_x)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
print(confusion_matrix(test_y,y_pred))
print("#############################################################")
print(classification_report(test_y,y_pred))
print("Visulization of  Confusion Matrix")
cm = confusion_matrix(test_y,y_pred)
sns.heatmap(cm,annot=True)
# Out:
# [[63  2]
#  [ 3 60]]
# #############################################################
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96        65
#            1       0.97      0.95      0.96        63
#
#     accuracy                           0.96       128
#    macro avg       0.96      0.96      0.96       128
# weighted avg       0.96      0.96      0.96       128
#
# Visulization of  Confusion Matrix

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(test_y,y_pred)
# Out:
# 0.9609375

# %% [markdown]
# # AdaBoostClassifier

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ada = AdaBoostClassifier()
ada.fit(training_x,training_y)
# Out:
# AdaBoostClassifier()

# %%
y_pred = ada.predict(test_x)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
print(confusion_matrix(test_y,y_pred))
print("#################################################################")
print(classification_report(test_y,y_pred))
print("Visulization of Confusion Matrix")
cm = confusion_matrix(test_y,y_pred)
sns.heatmap(cm,annot=True)
# Out:
# [[59  6]
#  [ 4 59]]
# #################################################################
#               precision    recall  f1-score   support
#
#            0       0.94      0.91      0.92        65
#            1       0.91      0.94      0.92        63
#
#     accuracy                           0.92       128
#    macro avg       0.92      0.92      0.92       128
# weighted avg       0.92      0.92      0.92       128
#
# Visulization of Confusion Matrix

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(test_y,y_pred)
# Out:
# 0.921875

# %% [markdown]
# # Xgboost Classifier

# %%
from xgboost import XGBClassifier

# %%
xgb = XGBClassifier()
xgb.fit(training_x,training_y)
# Out:
# XGBClassifier()

# %%
y_pred = xgb.predict(test_x)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
print(confusion_matrix(test_y,y_pred))
print("#####################################################")
print(classification_report(test_y,y_pred))
print("Visulization of Confusion Matrix")
cm = confusion_matrix(test_y,y_pred)
sns.heatmap(cm,annot=True)
# Out:
# [[63  2]
#  [ 3 60]]
# #####################################################
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96        65
#            1       0.97      0.95      0.96        63
#
#     accuracy                           0.96       128
#    macro avg       0.96      0.96      0.96       128
# weighted avg       0.96      0.96      0.96       128
#
# Visulization of Confusion Matrix

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(test_y,y_pred)
# Out:
# 0.9609375

# %% [markdown]
# # GradientBoostingClassifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc = GradientBoostingClassifier()
gbc.fit(training_x,training_y)
# Out:
# GradientBoostingClassifier()

# %%
y_pred = gbc.predict(test_x)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
print(confusion_matrix(test_y,y_pred))
print("########################################################")
print(classification_report(test_y,y_pred))
cm = confusion_matrix(test_y,y_pred)
sns.heatmap(cm,annot=True)
# Out:
# [[60  5]
#  [ 4 59]]
# ########################################################
#               precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93        65
#            1       0.92      0.94      0.93        63
#
#     accuracy                           0.93       128
#    macro avg       0.93      0.93      0.93       128
# weighted avg       0.93      0.93      0.93       128

# %% [markdown]
# # Naive Bayes Classifier

# %% [markdown]
# #GaussianNB
# #Multinomial
# #BernoulliNB

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB()
gnb.fit(training_x,training_y)
# Out:
# GaussianNB()

# %%
y_pred = gnb.predict(test_x)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
print(confusion_matrix(test_y,y_pred))
print("###########################################################3")
print(classification_report(test_y,y_pred))
print("Visulization of Confusion Matrix")
cm = confusion_matrix(test_y,y_pred)
sns.heatmap(cm,annot=True)
# Out:
# [[60  5]
#  [ 5 58]]
# ###########################################################3
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92        65
#            1       0.92      0.92      0.92        63
#
#     accuracy                           0.92       128
#    macro avg       0.92      0.92      0.92       128
# weighted avg       0.92      0.92      0.92       128
#
# Visulization of Confusion Matrix

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(test_y,y_pred)
# Out:
# 0.921875

# %% [markdown]
# #Multinomial

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
mnb = MultinomialNB()
mnb.fit(training_x,training_y)
# Out:
# MultinomialNB()

# %%
y_pred = mnb.predict(test_x)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
print(confusion_matrix(test_y,y_pred))
print("###########################################################3")
print(classification_report(test_y,y_pred))
print("Visulization of Confusion Matrix")
cm = confusion_matrix(test_y,y_pred)
sns.heatmap(cm,annot=True)
# Out:
# [[45 20]
#  [ 9 54]]
# ###########################################################3
#               precision    recall  f1-score   support
#
#            0       0.83      0.69      0.76        65
#            1       0.73      0.86      0.79        63
#
#     accuracy                           0.77       128
#    macro avg       0.78      0.77      0.77       128
# weighted avg       0.78      0.77      0.77       128
#
# Visulization of Confusion Matrix

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(test_y,y_pred)
# Out:
# 0.7734375

# %% [markdown]
# #BernoulliNB

# %%
from sklearn.naive_bayes import BernoulliNB

# %%
bnb = BernoulliNB()
bnb.fit(training_x,training_y)
# Out:
# BernoulliNB()

# %%
y_pred = bnb.predict(test_x)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
print(confusion_matrix(test_y,y_pred))
print("###########################################################3")
print(classification_report(test_y,y_pred))
print("Visulization of Confusion Matrix")
cm = confusion_matrix(test_y,y_pred)
sns.heatmap(cm,annot=True)
# Out:
# [[65  0]
#  [61  2]]
# ###########################################################3
#               precision    recall  f1-score   support
#
#            0       0.52      1.00      0.68        65
#            1       1.00      0.03      0.06        63
#
#     accuracy                           0.52       128
#    macro avg       0.76      0.52      0.37       128
# weighted avg       0.75      0.52      0.38       128
#
# Visulization of Confusion Matrix

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(test_y,y_pred)
# Out:
# 0.5234375

# %%
classifiers = {'LogisticRegression':lr, 'DecisionTreeClassifier':DT, 'KNeighborsClassifier':knn, 'SVC':svc,'GradientBoostingClassifier':gbc,
              'SGDClassifier':sgd, 'RandomForestClassifier':RFC, 'BaggingClassifier':BC, 'AdaBoostClassifier':ada,
              'XGBClassifier':xgb, 'GaussianNB':gnb, 'MultinomialNB':mnb, 'BernoulliNB':bnb}

# %%
classifier = sorted(classifiers.keys())
print(classifier)
# Out:
# ['AdaBoostClassifier', 'BaggingClassifier', 'BernoulliNB', 'DecisionTreeClassifier', 'GaussianNB', 'GradientBoostingClassifier', 'KNeighborsClassifier', 'LogisticRegression', 'MultinomialNB', 'RandomForestClassifier', 'SGDClassifier', 'SVC', 'XGBClassifier']

# %%
df = pd.DataFrame(classifier, columns=['Classifiers'])
df
# Out:
#                    Classifiers
# 0           AdaBoostClassifier
# 1            BaggingClassifier
# 2                  BernoulliNB
# 3       DecisionTreeClassifier
# 4                   GaussianNB
# 5   GradientBoostingClassifier
# 6         KNeighborsClassifier
# 7           LogisticRegression
# 8                MultinomialNB
# 9       RandomForestClassifier
# 10               SGDClassifier
# 11                         SVC
# 12               XGBClassifier

# %%
import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
parameter=[]
res=[]                                 
res=pd.DataFrame(res)
for n,c in sorted(classifiers.items()):                   
    kfold=StratifiedKFold(n_splits=10,random_state=None)  
    results=cross_val_score(c,X_under,y_under,cv=kfold)      
    parameter.append((n,[results.mean()]))                
    result=pd.DataFrame(results)                          
    res=pd.concat([res,result],axis=1,ignore_index=True) 
res.columns = ['AdaBoostClassifier', 'BaggingClassifier', 'BernoulliNB', 'DecisionTreeClassifier', 'GaussianNB', 'GradientBoostingClassifier', 'KNeighborsClassifier', 'LogisticRegression', 'MultinomialNB', 'RandomForestClassifier', 'SGDClassifier', 'SVC', 'XGBClassifier']
res
# Out:
#    AdaBoostClassifier  BaggingClassifier  BernoulliNB  DecisionTreeClassifier  \
# 0            0.976744           0.976744     0.534884                0.930233
# 1            0.906977           0.930233     0.534884                0.906977
# 2            0.906977           0.930233     0.534884                0.860465
# 3            0.930233           0.930233     0.534884                0.883721
# 4            0.976190           0.976190     0.500000                0.880952
# 5            0.976190           0.928571     0.500000                0.928571
# 6            0.928571           0.952381     0.547619                0.952381
# 7            0.904762           0.952381     0.523810                0.928571
# 8            0.976190           0.976190     0.523810                0.952381
# 9            0.928571           0.928571     0.523810                0.928571
#
#    GaussianNB  GradientBoostingClassifier  KNeighborsClassifier  \
# ...

# %% [markdown]
# # plot the figure

# %%
fig, ax=plt.subplots(figsize=(25,8))
sns.set(style='whitegrid')
boxplot = sns.boxplot(data=res, width=0.5)
boxplot.set_ylim([0.4,1.05])
fig.suptitle('Box plot of cross validation results',fontsize=25)
plt.xlabel("Classifiers",fontsize=25)
plt.ylabel('Accuracy',fontsize=25)
plt.tick_params(axis='both',which='major',colors='black',labelsize=10)
plt.show()

# %% [markdown]
# # Roc Curve Analysis

# %%
import time
import sklearn.metrics as metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.metrics import roc_auc_score
score = []
i=1
plt.subplots(figsize=(12,5))
for n,c in sorted(classifiers.items()):
    start=time.time()
    c.fit(training_x,training_y)
    pred=c.predict(test_x)
    end=time.time()

    print("{}) Classifier is : {}\n".format(i,c))
    print("Total time in : ",end-start)

    score.append((n,[accuracy_score(test_y,pred,normalize=True),metrics.precision_score(test_y,pred,average='micro'),
                    metrics.recall_score(test_y, pred,average='micro'),metrics.f1_score(test_y,pred,average='micro')]))
    
    print("\nConfusion_matrix is \n",confusion_matrix(test_y,pred))
    precision=print("\nPrecision : ",metrics.precision_score(test_y,pred,average='micro'))      
    recall=print("Recall    : ",metrics.recall_score(test_y,pred,average='micro'))
    f1_score=print("f1_score  : ",metrics.f1_score(test_y,pred,average='micro'))
    
    # ROC AND AUC CURVE                                                             
    fpr,tpr,thresholds=roc_curve(test_y,pred)
    # calculate AUC
    auc=roc_auc_score(test_y,pred)
    print('AUC: %.3f' % auc)

    i=i+1
       
    plt.plot(fpr,tpr,marker='.',label=n)
    
plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
# plot the roc curve for the model
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic and Area under the curve')
plt.legend()
plt.show()
# Out:
# 1) Classifier is : AdaBoostClassifier()
#
# Total time in :  0.48435306549072266
#
# Confusion_matrix is
#  [[59  6]
#  [ 4 59]]
#
# Precision :  0.921875
# Recall    :  0.921875
# f1_score  :  0.921875
# AUC: 0.922
# 2) Classifier is : BaggingClassifier()
#
# Total time in :  0.1093745231628418
#
# Confusion_matrix is
#  [[58  7]
#  [ 7 56]]
#
# Precision :  0.890625
# Recall    :  0.890625
# f1_score  :  0.890625
# AUC: 0.891
# 3) Classifier is : BernoulliNB()
#
# Total time in :  0.015618562698364258
#
# Confusion_matrix is
#  [[65  0]
#  [61  2]]
#
# Precision :  0.5234375
# Recall    :  0.5234375
# f1_score  :  0.5234375
# AUC: 0.516
# 4) Classifier is : DecisionTreeClassifier()
#
# Total time in :  0.0
#
# Confusion_matrix is
#  [[60  5]
#  [ 6 57]]
#
# Precision :  0.9140625
# Recall    :  0.9140625
# f1_score  :  0.9140625
# AUC: 0.914
# 5) Classifier is : GaussianNB()
#
# Total time in :  0.0
#
# Confusion_matrix is
#  [[60  5]
#  [ 5 58]]
#
# Precision :  0.921875
# ...

# %%
score = pd.DataFrame.from_dict(dict(score),orient='index', columns=['scores','Precision','Recall','f1_score'])
score['Accuracy (%)']=score['scores']*100
score
# Out:
#                               scores  Precision    Recall  f1_score  \
# AdaBoostClassifier          0.921875   0.921875  0.921875  0.921875
# BaggingClassifier           0.890625   0.890625  0.890625  0.890625
# BernoulliNB                 0.523438   0.523438  0.523438  0.523438
# DecisionTreeClassifier      0.914062   0.914062  0.914062  0.914062
# GaussianNB                  0.921875   0.921875  0.921875  0.921875
# GradientBoostingClassifier  0.929688   0.929688  0.929688  0.929688
# KNeighborsClassifier        0.968750   0.968750  0.968750  0.968750
# LogisticRegression          0.937500   0.937500  0.937500  0.937500
# MultinomialNB               0.773438   0.773438  0.773438  0.773438
# RandomForestClassifier      0.953125   0.953125  0.953125  0.953125
# SGDClassifier               0.953125   0.953125  0.953125  0.953125
# SVC                         0.960938   0.960938  0.960938  0.960938
# XGBClassifier               0.960938   0.960938  0.960938  0.960938
#
# ...

# %%
pos = list(range(len(df['Classifiers']))) 
width = 0.10 
    
# Plotting the bars
fig, ax = plt.subplots(figsize=(22,10)) 
plt.bar(pos,score['scores'],width,alpha=0.9,color='red',label=score['scores'][0]) 
plt.bar([p + width for p in pos],score['Precision'],width,alpha=0.9,color='turquoise',label=score['Precision'][1]) 
plt.bar([p + width*2 for p in pos],score['Recall'],width,alpha=0.9, color='orange',label=score['Recall']) 
plt.bar([p + width*3 for p in pos],score['f1_score'],width,alpha=0.9, color='green',label=score['f1_score']) 
ax.set_ylabel('Score',fontsize=25)
ax.set_xlabel('Classifiers',fontsize=25)
ax.set_title('Test Scores ',fontsize=25)
ax.set_xticks([p + 1.9 * width for p in pos])
ax.set_xticklabels(df['Classifiers'])
plt.legend(['scores', 'Precision', 'recall','f1_score'], loc='upper left')
plt.grid()
plt.tick_params(axis='both', which='major', colors='black',labelsize=10)

plt.show()
